# %% [markdown]
# ## inline test

# %%
# !python ./tsne.py
# Out:
# Run Y = tsne.tsne(X, no_dims, perplexity) to perform t-SNE on your dataset.
# Running example on 2,500 MNIST digits...
# Preprocessing the data using PCA...
# Computing pairwise distances...
# Computing P-values for point 0 of 2500...
# Computing P-values for point 500 of 2500...
# Computing P-values for point 1000 of 2500...
# Computing P-values for point 1500 of 2500...
# Computing P-values for point 2000 of 2500...
# Mean value of sigma: 2.386597
# Iteration 10: error is 23.537461
# Iteration 20: error is 20.982627
# Iteration 30: error is 17.890803
# Iteration 40: error is 16.699286
# Iteration 50: error is 16.436435
# Iteration 60: error is 16.304636
# Iteration 70: error is 16.175964
# Iteration 80: error is 16.059978
# Iteration 90: error is 15.983471
# Iteration 100: error is 15.928021
# Iteration 110: error is 2.303298
# Iteration 120: error is 2.066579
# Iteration 130: error is 1.885280
# Iteration 140: error is 1.747905
# Iteration 150: error is 1.642345
# Iteration 160: error is 1.559145
# Iteration 170: error is 1.493070
# Iteration 180: error is 1.439014
# Iteration 190: error is 1.393933
# Iteration 200: error is 1.355929
# Iteration 210: error is 1.323723
# Iteration 220: error is 1.296116
# Iteration 230: error is 1.272297
# Iteration 240: error is 1.251626
# Iteration 250: error is 1.233356
# Iteration 260: error is 1.217113
# Iteration 270: error is 1.202612
# Iteration 280: error is 1.189580
# Iteration 290: error is 1.177842
# Iteration 300: error is 1.167239
# Iteration 310: error is 1.157631
# Iteration 320: error is 1.148852
# Iteration 330: error is 1.140819
# Iteration 340: error is 1.133431
# Iteration 350: error is 1.126578
# Iteration 360: error is 1.120320
# Iteration 370: error is 1.114553
# Iteration 380: error is 1.109199
# Iteration 390: error is 1.104188
# Iteration 400: error is 1.099477
# Iteration 410: error is 1.095081
# Iteration 420: error is 1.090971
# Iteration 430: error is 1.087128
# Iteration 440: error is 1.083536
# Iteration 450: error is 1.080151
# Iteration 460: error is 1.076943
# Iteration 470: error is 1.073899
# Iteration 480: error is 1.071019
# Iteration 490: error is 1.068302
# Iteration 500: error is 1.065734
# Iteration 510: error is 1.063298
# Iteration 520: error is 1.060990
# Iteration 530: error is 1.058799
# Iteration 540: error is 1.056722
# Iteration 550: error is 1.054742
# Iteration 560: error is 1.052849
# Iteration 570: error is 1.051040
# Iteration 580: error is 1.049308
# Iteration 590: error is 1.047648
# Iteration 600: error is 1.046064
# Iteration 610: error is 1.044554
# Iteration 620: error is 1.043106
# Iteration 630: error is 1.041717
# Iteration 640: error is 1.040387
# Iteration 650: error is 1.039115
# Iteration 660: error is 1.037895
# Iteration 670: error is 1.036721
# Iteration 680: error is 1.035594
# Iteration 690: error is 1.034507
# Iteration 700: error is 1.033454
# Iteration 710: error is 1.032440
# Iteration 720: error is 1.031463
# Iteration 730: error is 1.030519
# Iteration 740: error is 1.029608
# Iteration 750: error is 1.028729
# Iteration 760: error is 1.027878
# Iteration 770: error is 1.027056
# Iteration 780: error is 1.026265
# Iteration 790: error is 1.025505
# Iteration 800: error is 1.024770
# Iteration 810: error is 1.024056
# Iteration 820: error is 1.023364
# Iteration 830: error is 1.022690
# Iteration 840: error is 1.022036
# Iteration 850: error is 1.021402
# Iteration 860: error is 1.020788
# Iteration 870: error is 1.020194
# Iteration 880: error is 1.019616
# Iteration 890: error is 1.019055
# Iteration 900: error is 1.018508
# Iteration 910: error is 1.017978
# Iteration 920: error is 1.017464
# Iteration 930: error is 1.016967
# Iteration 940: error is 1.016483
# Iteration 950: error is 1.016011
# Iteration 960: error is 1.015551
# Iteration 970: error is 1.015103
# Iteration 980: error is 1.014666
# Iteration 990: error is 1.014241
# Iteration 1000: error is 1.013826
# Figure(640x480)

# %% [markdown]
# ```#
# #  tsne.py
# #
# # Implementation of t-SNE in Python. The implementation was tested on Python
# # 2.7.10, and it requires a working installation of NumPy. The implementation
# # comes with an example on the MNIST dataset. In order to plot the
# # results of this example, a working installation of matplotlib is required.
# #
# # The example can be run by executing: `ipython tsne.py`
# #
# #
# #  Created by Laurens van der Maaten on 20-12-08.
# #  Copyright (c) 2008 Tilburg University. All rights reserved```

# %% [markdown]
# ## test here

# %%
def Hbeta(D=np.array([]), beta=1.0):
    """
        Compute the perplexity and the P-row for a specific value of the
        precision of a Gaussian distribution.
    """

    # Compute P-row and corresponding perplexity
    P = np.exp(-D.copy() * beta)
    sumP = sum(P)
    H = np.log(sumP) + beta * np.sum(D * P) / sumP
    P = P / sumP
    return H, P

# %%
def x2p(X=np.array([]), tol=1e-5, perplexity=30.0):
    """
        Performs a binary search to get P-values in such a way that each
        conditional Gaussian has the same perplexity.
    """

    # Initialize some variables
    print("Computing pairwise distances...")
    (n, d) = X.shape
    sum_X = np.sum(np.square(X), 1)
    D = np.add(np.add(-2 * np.dot(X, X.T), sum_X).T, sum_X)
    P = np.zeros((n, n))
    beta = np.ones((n, 1))
    logU = np.log(perplexity)

    # Loop over all datapoints
    for i in range(n):

        # Print progress
        if i % 10 == 0:
            print("Computing P-values for point %d of %d..." % (i, n) + '\r', end='')

        # Compute the Gaussian kernel and entropy for the current precision
        betamin = -np.inf
        betamax = np.inf
        Di = D[i, np.concatenate((np.r_[0:i], np.r_[i+1:n]))]
        (H, thisP) = Hbeta(Di, beta[i])

        # Evaluate whether the perplexity is within tolerance
        Hdiff = H - logU
        tries = 0
        while np.abs(Hdiff) > tol and tries < 50:

            # If not, increase or decrease precision
            if Hdiff > 0:
                betamin = beta[i].copy()
                if betamax == np.inf or betamax == -np.inf:
                    beta[i] = beta[i] * 2.
                else:
                    beta[i] = (beta[i] + betamax) / 2.
            else:
                betamax = beta[i].copy()
                if betamin == np.inf or betamin == -np.inf:
                    beta[i] = beta[i] / 2.
                else:
                    beta[i] = (beta[i] + betamin) / 2.

            # Recompute the values
            (H, thisP) = Hbeta(Di, beta[i])
            Hdiff = H - logU
            tries += 1

        # Set the final row of P
        P[i, np.concatenate((np.r_[0:i], np.r_[i+1:n]))] = thisP

    # Return final P-matrix
    print()
    print("Mean value of sigma: %f" % np.mean(np.sqrt(1 / beta)))
    return P

# %%
def pca(X=np.array([]), no_dims=50):
    """
        Runs PCA on the NxD array X in order to reduce its dimensionality to
        no_dims dimensions.
    """

    print("Preprocessing the data using PCA...")
    (n, d) = X.shape
    X = X - np.tile(np.mean(X, 0), (n, 1))
    (l, M) = np.linalg.eig(np.dot(X.T, X))
    Y = np.dot(X, M[:, 0:no_dims])
    return Y

# %%
def tsne(X=np.array([]), no_dims=2, initial_dims=50, perplexity=30.0):
    """
        Runs t-SNE on the dataset in the NxD array X to reduce its
        dimensionality to no_dims dimensions. The syntaxis of the function is
        `Y = tsne.tsne(X, no_dims, perplexity), where X is an NxD NumPy array.
    """

    # Check inputs
    if isinstance(no_dims, float):
        print("Error: array X should have type float.")
        return -1
    if round(no_dims) != no_dims:
        print("Error: number of dimensions should be an integer.")
        return -1

    # Initialize variables
    X = pca(X, initial_dims).real
    (n, d) = X.shape
    max_iter = 1000
    initial_momentum = 0.5
    final_momentum = 0.8
    eta = 500
    min_gain = 0.01
    Y = np.random.randn(n, no_dims)
    dY = np.zeros((n, no_dims))
    iY = np.zeros((n, no_dims))
    gains = np.ones((n, no_dims))

    # Compute P-values
    P = x2p(X, 1e-5, perplexity)
    P = P + np.transpose(P)
    P = P / np.sum(P)
    P = P * 4.									# early exaggeration
    P = np.maximum(P, 1e-12)

    # Run iterations
    for iter in range(max_iter):

        # Compute pairwise affinities
        sum_Y = np.sum(np.square(Y), 1)
        num = -2. * np.dot(Y, Y.T)
        num = 1. / (1. + np.add(np.add(num, sum_Y).T, sum_Y))
        num[range(n), range(n)] = 0.
        Q = num / np.sum(num)
        Q = np.maximum(Q, 1e-12)

        # Compute gradient
        PQ = P - Q
        for i in range(n):
            dY[i, :] = np.sum(np.tile(PQ[:, i] * num[:, i], (no_dims, 1)).T * (Y[i, :] - Y), 0)

        # Perform the update
        if iter < 20:
            momentum = initial_momentum
        else:
            momentum = final_momentum
        gains = (gains + 0.2) * ((dY > 0.) != (iY > 0.)) + \
                (gains * 0.8) * ((dY > 0.) == (iY > 0.))
        gains[gains < min_gain] = min_gain
        iY = momentum * iY - eta * (gains * dY)
        Y = Y + iY
        Y = Y - np.tile(np.mean(Y, 0), (n, 1))

        # Compute current value of cost function
        if (iter + 1) % 10 == 0:
            C = np.sum(P * np.log(P / Q))
            print("Iteration %d: error is %f" % (iter + 1, C))

        # Stop lying about P-values
        if iter == 100:
            P = P / 4.

    # Return solution
    return Y

# %%
# if __name__ == "__main__":
print("Run Y = tsne.tsne(X, no_dims, perplexity) to perform t-SNE on your dataset.")
print("Running example on 2,500 MNIST digits...")
X = np.loadtxt("mnist2500_X.txt")
labels = np.loadtxt("mnist2500_labels.txt")
Y = tsne(X, 2, 50, 20.0)
Y.shape
# Out:
# Run Y = tsne.tsne(X, no_dims, perplexity) to perform t-SNE on your dataset.
# Running example on 2,500 MNIST digits...
# Preprocessed the data using PCA....
# Computing pairwise distances...
# Computing P-values for point 2490 of 2500...
# Mean value of sigma: 2.386597
# Iteration 10: error is 23.533253
# Iteration 20: error is 21.100955
# Iteration 30: error is 18.150792
# Iteration 40: error is 17.042080
# Iteration 50: error is 16.749627
# Iteration 60: error is 16.607142
# Iteration 70: error is 16.433892
# Iteration 80: error is 16.296473
# Iteration 90: error is 16.220220
# Iteration 100: error is 16.164927
# Iteration 110: error is 2.391750
# Iteration 120: error is 2.140915
# Iteration 130: error is 1.945412
# Iteration 140: error is 1.798187
# Iteration 150: error is 1.685770
# Iteration 160: error is 1.598809
# Iteration 170: error is 1.529711
# Iteration 180: error is 1.473539
# Iteration 190: error is 1.427036
# Iteration 200: error is 1.388235
# Iteration 210: error is 1.355351
# Iteration 220: error is 1.327212
# Iteration 230: error is 1.303144
# Iteration 240: error is 1.282227
# Iteration 250: error is 1.263821
# Iteration 260: error is 1.247558
# Iteration 270: error is 1.233077
# Iteration 280: error is 1.220040
# Iteration 290: error is 1.208307
# Iteration 300: error is 1.197684
# Iteration 310: error is 1.188031
# Iteration 320: error is 1.179211
# Iteration 330: error is 1.171100
# Iteration 340: error is 1.163631
# Iteration 350: error is 1.156736
# Iteration 360: error is 1.150348
# Iteration 370: error is 1.144447
# Iteration 380: error is 1.139001
# Iteration 390: error is 1.133934
# Iteration 400: error is 1.129177
# Iteration 410: error is 1.124709
# Iteration 420: error is 1.120525
# Iteration 430: error is 1.116588
# Iteration 440: error is 1.112865
# Iteration 450: error is 1.109363
# Iteration 460: error is 1.106072
# Iteration 470: error is 1.102945
# Iteration 480: error is 1.099946
# Iteration 490: error is 1.097070
# Iteration 500: error is 1.094245
# Iteration 510: error is 1.091669
# Iteration 520: error is 1.089238
# Iteration 530: error is 1.086921
# Iteration 540: error is 1.084729
# Iteration 550: error is 1.082633
# Iteration 560: error is 1.080622
# Iteration 570: error is 1.078682
# Iteration 580: error is 1.076809
# Iteration 590: error is 1.074999
# Iteration 600: error is 1.073244
# Iteration 610: error is 1.071543
# Iteration 620: error is 1.069890
# Iteration 630: error is 1.068289
# Iteration 640: error is 1.066724
# Iteration 650: error is 1.065199
# Iteration 660: error is 1.063754
# Iteration 670: error is 1.062350
# Iteration 680: error is 1.061056
# Iteration 690: error is 1.059823
# Iteration 700: error is 1.058637
# Iteration 710: error is 1.057483
# Iteration 720: error is 1.056353
# Iteration 730: error is 1.055240
# Iteration 740: error is 1.054122
# Iteration 750: error is 1.052931
# Iteration 760: error is 1.051640
# Iteration 770: error is 1.050622
# Iteration 780: error is 1.049760
# Iteration 790: error is 1.048954
# Iteration 800: error is 1.048184
# Iteration 810: error is 1.047443
# Iteration 820: error is 1.046729
# Iteration 830: error is 1.046036
# Iteration 840: error is 1.045364
# Iteration 850: error is 1.044713
# Iteration 860: error is 1.044081
# Iteration 870: error is 1.043467
# Iteration 880: error is 1.042872
# Iteration 890: error is 1.042291
# Iteration 900: error is 1.041727
# Iteration 910: error is 1.041179
# Iteration 920: error is 1.040647
# Iteration 930: error is 1.040130
# Iteration 940: error is 1.039625
# Iteration 950: error is 1.039130
# Iteration 960: error is 1.038644
# Iteration 970: error is 1.038156
# Iteration 980: error is 1.037669
# Iteration 990: error is 1.037188
# Iteration 1000: error is 1.036722
# (2500, 2)

# %%
pd.to_pickle(Y, './mnist2500_res_X.pkl')

# %%
Y = pd.read_pickle('./mnist2500_res_X.pkl')
Y.shape

# %% [markdown]
# ## viz

# %%
import pylab

# %%
pylab.scatter(Y[:, 0], Y[:, 1], 20, labels)
pylab.show()
